# %% [markdown]
# ## To submit this assignment, please solve the following problem. Then, save your notebook with the format [YOUR_NETID]\_DescriptiveAnalysis_Homework and submit via NYU Classes.

# %% [markdown]
# ---

# %% [markdown]
# ### For this assignment, you must:
#
# <br> 1. Download the CSV found here:
# https://data.cityofnewyork.us/Health/DOHMH-Childcare-Center-Inspections/dsg6-ifza <br>
# <br> 2. Create a Pandas DataFrame from said CSV. <br>
# <br> 3. Answer the following questions:
#  - What is the most common program type inspected in 2018?
#  - What is the violation status for every inspection that took place in May, 2018

# %%
import pandas as pd

df = pd.read_csv("DOHMH_Childcare_Center_Inspections.csv",low_memory=False)
# %matplotlib inline

df.head()
# Out:
#              Center Name  ...                          Inspection Summary Result
# 0     YESHIVAT OHR HAIIM  ...  Compliance Inspection of Open Violations - Pre...
# 1  TINY BUMBLEBEES, INC.  ...  Initial Annual Inspection - Reinspection Requi...
# 2     YESHIVAT OHR HAIIM  ...  Initial Annual Inspection - Reinspection Required
# 3     YESHIVAT OHR HAIIM  ...  Initial Annual Inspection - Reinspection Required
# 4                   SBCC  ...  Compliance Inspection of Open Violations - Rei...
#
# [5 rows x 34 columns]

# %%
df.dtypes
# Out:
# Center Name                                     object
# Legal Name                                      object
# Building                                        object
# Street                                          object
# Borough                                         object
# ZipCode                                        float64
# Phone                                           object
# Permit Number                                  float64
# Permit Expiration                               object
# Status                                          object
# Age Range                                       object
# Maximum Capacity                                 int64
# Day Care ID                                     object
# Program Type                                    object
# Facility Type                                   object
# Child Care Type                                 object
# Building Identification Number                   int64
# URL                                             object
# Date Permitted                                  object
# Actual                                          object
# Violation Rate Percent                         float64
# Average Violation Rate Percent                 float64
# Total Educational Workers                        int64
# Average Total Educational Workers              float64
# Public Health Hazard Violation Rate            float64
# Average Public Health Hazard Violation Rate    float64
# Critical Violation Rate                        float64
# Average Critical Violation Rate                float64
# Inspection Date                                 object
# Regulation Summary                              object
# Violation Category                              object
# Health Code Sub Section                         object
# Violation Status                                object
# Inspection Summary Result                       object
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                               Center Name  ...                          Inspection Summary Result
# 0                      YESHIVAT OHR HAIIM  ...  Compliance Inspection of Open Violations - Pre...
# 1                   TINY BUMBLEBEES, INC.  ...  Initial Annual Inspection - Reinspection Requi...
# 2                      YESHIVAT OHR HAIIM  ...  Initial Annual Inspection - Reinspection Required
# 3                      YESHIVAT OHR HAIIM  ...  Initial Annual Inspection - Reinspection Required
# 4                                    SBCC  ...  Compliance Inspection of Open Violations - Rei...
# ...                                   ...  ...                                                ...
# 45916  KINDERCARE EDUCATION AT WORK, LLC.  ...  Initial Annual Inspection - Reinspection Requi...
# 45917              LEADING KIDS PRESCHOOL  ...  Initial Annual Inspection - Reinspection Requi...
# 45918   VACATION BIBLE SCHOOL SUMMER CAMP  ...  Initial Annual Inspection - Passed inspection ...
# 45919               SCO FAMILY OF SERVICE  ...  Monitoring Inspection Non-Routine - Reinspecti...
# 45920    KA OF STATEN ISLAND -GREAT KILLS  ...                                                NaN
#
# [45921 rows x 34 columns]>

# %%
df['Inspection Date'] = pd.to_datetime(df['Inspection Date'])
df
# Out:
#                               Center Name  ...                          Inspection Summary Result
# 0                      YESHIVAT OHR HAIIM  ...  Compliance Inspection of Open Violations - Pre...
# 1                   TINY BUMBLEBEES, INC.  ...  Initial Annual Inspection - Reinspection Requi...
# 2                      YESHIVAT OHR HAIIM  ...  Initial Annual Inspection - Reinspection Required
# 3                      YESHIVAT OHR HAIIM  ...  Initial Annual Inspection - Reinspection Required
# 4                                    SBCC  ...  Compliance Inspection of Open Violations - Rei...
# ...                                   ...  ...                                                ...
# 45916  KINDERCARE EDUCATION AT WORK, LLC.  ...  Initial Annual Inspection - Reinspection Requi...
# 45917              LEADING KIDS PRESCHOOL  ...  Initial Annual Inspection - Reinspection Requi...
# 45918   VACATION BIBLE SCHOOL SUMMER CAMP  ...  Initial Annual Inspection - Passed inspection ...
# 45919               SCO FAMILY OF SERVICE  ...  Monitoring Inspection Non-Routine - Reinspecti...
# 45920    KA OF STATEN ISLAND -GREAT KILLS  ...                                                NaN
#
# [45921 rows x 34 columns]

# %%
df['Program Type'].value_counts()
# Out:
# PRESCHOOL          39004
# INFANT TODDLER      6264
# ALL AGE CAMP         602
# Preschool             19
# SCHOOL AGE CAMP       16
# PRESCHOOL CAMP         8
# Preschool Camp         5
# All Age Camp           2
# Infant Toddler         1
# Name: Program Type, dtype: int64

# %%
#What is the most common program type inspected in 2018?
df = df.set_index('Inspection Date')

# %%
df2018 = df['2018']
df2018
# Out:
#                                             Center Name  ...                          Inspection Summary Result
# Inspection Date                                          ...
# 2018-05-30                           YESHIVAT OHR HAIIM  ...  Compliance Inspection of Open Violations - Pre...
# 2018-04-17                           YESHIVAT OHR HAIIM  ...  Initial Annual Inspection - Reinspection Required
# 2018-02-06                                         SBCC  ...  Compliance Inspection of Open Violations - Rei...
# 2018-04-11                       TALMUD TORAH OHR MOSHE  ...  Initial Annual Inspection - Passed inspection ...
# 2018-11-29       Our Lady of the Snows Catholic Academy  ...  Initial Annual Inspection - Reinspection Required
# ...                                                 ...  ...                                                ...
# 2018-01-25           KINDERCARE EDUCATION AT WORK, LLC.  ...  Initial Annual Inspection - Reinspection Requi...
# 2018-01-25           KINDERCARE EDUCATION AT WORK, LLC.  ...  Initial Annual Inspection - Reinspection Requi...
# 2018-02-07                       LEADING KIDS PRESCHOOL  ...  Initial Annual Inspection - Reinspection Requi...
# 2018-07-31            VACATION BIBLE SCHOOL SUMMER CAMP  ...  Initial Annual Inspection - Passed inspection ...
# 2018-09-26                        SCO FAMILY OF SERVICE  ...  Monitoring Inspection Non-Routine - Reinspecti...
#
# [18812 rows x 33 columns]

# %%
df2018['Program Type'].value_counts()
# Out:
# PRESCHOOL          16122
# INFANT TODDLER      2499
# ALL AGE CAMP         175
# Preschool             14
# SCHOOL AGE CAMP        2
# Name: Program Type, dtype: int64

# %%
print('The most common program type inspected in 2018 is PRESCHOOL')
# Out:
# The most common program type inspected in 2018 is PRESCHOOL

# %%
#What is the violation status for every inspection that took place in May, 2018?
dfMay2018 = df['2018-05']
dfMay2018
# Out:
#                                          Center Name  ...                          Inspection Summary Result
# Inspection Date                                       ...
# 2018-05-30                        YESHIVAT OHR HAIIM  ...  Compliance Inspection of Open Violations - Pre...
# 2018-05-18            BRIGHT HORIZONS AT KENT AVENUE  ...  Initial Annual Inspection - Reinspection Requi...
# 2018-05-18            BRIGHT HORIZONS AT KENT AVENUE  ...  Initial Annual Inspection - Reinspection Requi...
# 2018-05-18            BRIGHT HORIZONS AT KENT AVENUE  ...  Initial Annual Inspection - Reinspection Requi...
# 2018-05-30                        PARK PLACE DAYCARE  ...  Initial Annual Inspection - Reinspection Requi...
# ...                                              ...  ...                                                ...
# 2018-05-31                     YALDAYNU CENTER, INC.  ...  Initial Annual Inspection - Passed inspection ...
# 2018-05-02                        AHI EZER PRESCHOOL  ...  Initial Annual Inspection - Reinspection Required
# 2018-05-30       SHIRLEY CHISHOLM DAY CARE CENTER #4  ...  Monitoring Inspection Non-Routine - Previously...
# 2018-05-09                  RENANIM  MANHATTAN, INC.  ...  Initial Annual Inspection - Reinspection Not R...
# 2018-05-03          CHILDREN'S PALACE DAY CARE, INC.  ...  Initial Annual Inspection - Reinspection Requi...
#
# [2448 rows x 33 columns]

# %%
dfMay2018['Violation Status']
# Out:
# Inspection Date
# 2018-05-30          NaN
# 2018-05-18    CORRECTED
# 2018-05-18    CORRECTED
# 2018-05-18    CORRECTED
# 2018-05-30    CORRECTED
#                 ...
# 2018-05-31          NaN
# 2018-05-02    CORRECTED
# 2018-05-30          NaN
# 2018-05-09    CORRECTED
# 2018-05-03    CORRECTED
# Name: Violation Status, Length: 2448, dtype: object
